# %% [markdown]
# <a href="https://colab.research.google.com/github/rejinadel/Pandas/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/sample_data/california_housing_train.csv')
df.mean()
# Out:
# longitude               -119.562108
# latitude                  35.625225
# housing_median_age        28.589353
# total_rooms             2643.664412
# total_bedrooms           539.410824
# population              1429.573941
# households               501.221941
# median_income              3.883578
# median_house_value    207300.912353
# dtype: float64

# %%
import pandas as pd
df = pd.read_csv('/content/sample_data/california_housing_train.csv')
df.households.value_counts()
# Out:
# 306.0     48
# 386.0     48
# 282.0     47
# 330.0     46
# 426.0     45
#           ..
# 3671.0     1
# 1437.0     1
# 2731.0     1
# 1129.0     1
# 992.0      1
# Name: households, Length: 1740, dtype: int64

# %%
import pandas as pd
df = pd.read_csv('/content/sample_data/california_housing_train.csv')
df.sort_values(by = 'population')
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8232     -118.44     34.04                16.0         18.0             6.0
# 2990     -117.79     35.21                 4.0          2.0             2.0
# 2907     -117.76     35.22                 4.0         18.0             3.0
# 14105    -122.06     37.39                26.0         18.0             4.0
# 288      -116.76     34.14                 4.0         42.0            10.0
# ...          ...       ...                 ...          ...             ...
# 3296     -117.87     34.04                 7.0      27700.0          4179.0
# 2969     -117.78     34.03                 8.0      32054.0          5290.0
# 2871     -117.74     33.89                 4.0      37937.0          5471.0
# 12772    -121.79     36.64                11.0      32627.0          6445.0
# 2274     -117.42     33.35                14.0      25135.0          4819.0
#
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/sample_data/california_housing_train.csv')
df.sort_values(by = 'population',ascending = False).head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2274     -117.42     33.35                14.0      25135.0          4819.0
# 12772    -121.79     36.64                11.0      32627.0          6445.0
# 2871     -117.74     33.89                 4.0      37937.0          5471.0
# 2969     -117.78     34.03                 8.0      32054.0          5290.0
# 3296     -117.87     34.04                 7.0      27700.0          4179.0
#
#        population  households  median_income  median_house_value
# 2274      35682.0      4769.0         2.5729            134400.0
# 12772     28566.0      6082.0         2.3087            118800.0
# 2871      16122.0      5189.0         7.4947            366300.0
# 2969      15507.0      5050.0         6.0191            253900.0
# 3296      15037.0      4072.0         6.6288            339700.0

# %%
import pandas as pd
df = pd.read_csv('/content/sample_data/california_housing_train.csv')
df['population'].sort_values(ascending = False)[:5]
# Out:
# 2274     35682.0
# 12772    28566.0
# 2871     16122.0
# 2969     15507.0
# 3296     15037.0
# Name: population, dtype: float64

# %%
import pandas as pd
df = pd.read_csv('/content/sample_data/california_housing_train.csv')
df.rename(columns = {'population' : 'people','total_rooms':'rooms'}, inplace = True)
df.head()
# Out:
#    longitude  latitude  housing_median_age   rooms  total_bedrooms  people  \
# 0    -114.31     34.19                15.0  5612.0          1283.0  1015.0
# 1    -114.47     34.40                19.0  7650.0          1901.0  1129.0
# 2    -114.56     33.69                17.0   720.0           174.0   333.0
# 3    -114.57     33.64                14.0  1501.0           337.0   515.0
# 4    -114.57     33.57                20.0  1454.0           326.0   624.0
#
#    households  median_income  median_house_value
# 0       472.0         1.4936             66900.0
# 1       463.0         1.8200             80100.0
# 2       117.0         1.6509             85700.0
# 3       226.0         3.1917             73400.0
# 4       262.0         1.9250             65500.0

# %%
from tables.index import Index
import pandas as pd
df = pd.read_csv('/content/sample_data/california_housing_train.csv')
df.rename(index ={0:'zero', 1:'one'})
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# zero     -114.31     34.19                15.0       5612.0          1283.0
# one      -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/sample_data/california_housing_train.csv')
df.isnull()
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64
